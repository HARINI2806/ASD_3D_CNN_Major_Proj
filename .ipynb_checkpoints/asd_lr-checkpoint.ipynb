# %% [markdown]
# # EARLY DETECTION OF ASD ON CLINICAL DATA USING MACHINE LEARNING ALGORITHMS

# %% [markdown]
# # IMPORT STATEMENTS

# %% [markdown]
# matplotlib.pyplot is a collection of command style functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
#
# Seaborn is a library for making statistical graphics in Python.
#
# pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.
#
# The sklearn.preprocessing package provides several common utility functions and transformer classes to change raw feature vectors into a representation that is more suitable for the downstream estimators.
#
# train_test_split is a function in Sklearn model selection for splitting data arrays into two subsets: for training data and for testing data. With this function, you don't need to divide the dataset manually.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %% [markdown]
# read_csv is an important pandas function to read csv files and do operations on it.

# %%
columns = ["A1_Score", "A2_Score","A3_Score", "A4_Score","A5_Score","A6_Score" ,"A7_Score", "A8_Score","A9_Score", "A10_Score","Age","gender" ,"ethnicity" ,"jundice" ,"austim","contry_of_res","used_app_before","result","age_desc","relation","ASDLabel"]

# %%
dataset = pd.read_csv("C:/Users/User/ASD_Projs/autism_spectrum_detection-main-T9/project_autism.csv", names=columns, sep=' *, *', na_values='?', engine='python')

# %% [markdown]
# The value_counts() method returns a Series containing the counts of unique values. This means, for any column in a dataframe, this method returns the count of unique entries in that column.

# %%
dataset.shape
# Out:
# (704, 21)

# %%
dataset =dataset.drop_duplicates(keep='first')
dataset = dataset.dropna()

# %%
dataset['gender'] = dataset['gender'].map({'m':1,'f':0})

# %%
dataset['jundice'] = dataset['jundice'].map({'yes':1,'no':0})
dataset['austim']=dataset['austim'].map({'yes':1,'no':0})
dataset['used_app_before']=dataset['used_app_before'].map({'yes':1,'no':0})
dataset['ASDLabel']=dataset['ASDLabel'].map({'YES':1,'NO':0})

# %%
#dropping age_desc because it is of no use
dataset.drop(['age_desc'], axis=1, inplace=True)
dataset.drop(['contry_of_res'], axis=1, inplace=True)
dataset.drop(['ethnicity'], axis=1, inplace=True)
dataset.drop(['relation'], axis=1, inplace=True)

# %%
dataset['ASDLabel'].value_counts()
# Out:
# 0    426
# 1    178
# Name: ASDLabel, dtype: int64

# %% [markdown]
# method plt.pie() is used to create a plot.
#
# plt.show() is used to display the figure.
#
# The countplot plot can be thought of as a histogram across a categorical variable.

# %%
# plt.pie(dataset['ASDLabel'].value_counts(), labels=['0','1'], autopct='%1.1f%%', shadow=True)
# plt.show()
# sns.countplot(dataset['ASDLabel'], label="Count")
# plt.show()

# %% [markdown]
# Resample arrays or sparse matrices in a consistent way.

# %%
from sklearn.utils import resample
df_majority = dataset[dataset.ASDLabel==0]
df_minority = dataset[dataset.ASDLabel==1]

# %% [markdown]
# The resample() function is used to resample time-series data.

# %%
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=515,    # to match majority class
                                 random_state=123) # reproducible results

# %% [markdown]
# The concat() function does all of the heavy lifting of performing concatenation operations along an axis while performing optional set logic of the indexes on the other axes.

# %%
df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# %%
df_upsampled.ASDLabel.value_counts()
# Out:
# 1    515
# 0    426
# Name: ASDLabel, dtype: int64

# %%
plt.pie(df_upsampled['ASDLabel'].value_counts(), labels=['1','0'], autopct='%1.1f%%', shadow=True)
plt.show()
sns.countplot(df_upsampled['ASDLabel'], label="Count")
plt.show()
# Out:
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Now that we've read our dataset.
#
# Create dataset X by excluding label column

# %%
X = df_upsampled[df_upsampled.columns[0:16]].values

# %% [markdown]
# Create dataset Y by only label column

# %%
Y = df_upsampled[df_upsampled.columns[16:]].values

# %% [markdown]
# Printing dimensions of sepsis dataset

# %%
print("ASD dimensions : {}".format(df_upsampled.shape))
# Out:
# ASD dimensions : (941, 17)

# %% [markdown]
# Printing dimensions of sepsis dataset without label column

# %%
print("ASD dimensions without label : {}".format(X.shape))
# Out:
# ASD dimensions without label : (941, 16)

# %% [markdown]
# Printing dimensions of sepsis dataset only with label column

# %%
print("ASD dimensions only label : {}".format(Y.shape))
# Out:
# ASD dimensions only label : (941, 1)

# %% [markdown]
# LabelEncoder is used to normalize labels.

# %%
labelencoder_Y = preprocessing.LabelEncoder()
Y = labelencoder_Y.fit_transform(Y)
# Out:
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# For splitting data into train set and test set, train_test_split function is used

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=0)
print("Training data dimensions :{}".format(X_train.shape))
print("Testing data dimensions :{}".format(X_test.shape))
# Out:
# Training data dimensions :(752, 16)
# Testing data dimensions :(189, 16)

# %% [markdown]
# # Comparing Machine Learning Algorithms Consistently

# %% [markdown]
# The key to a fair comparison of machine learning algorithms is ensuring that each algorithm is evaluated in the same way on the same data.
#
# You can achieve this by forcing each algorithm to be evaluated on a consistent test harness.

# %% [markdown]
# In the followin code, we have considered the following machine learning algorithms
#
# MLP Classifier,
#
# AdaBoost Classifier,
#
# Gradient Boosting Classifier,
#
# GaussianNB,
#
# Linear Discriminant Analysis,
#
# Quadratic Discriminant Analysis.
#
# And also print the accuracy for the algorithms mentioned above respectively.

# %%
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
classifiers = [
     MLPClassifier(
     activation='tanh',
     solver='lbfgs',
     early_stopping=False,
     hidden_layer_sizes=(40,10,10,10,10, 2),
     random_state=1,
     batch_size='auto',
     max_iter=13000,
     learning_rate_init=1e-5,
     tol=1e-4,
 ),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis()]

# Logging for Visual Comparison
log_cols=["Classifier", "Accuracy", "Log Loss"]
log = pd.DataFrame(columns=log_cols)

for clf in classifiers:
    clf.fit(X_train, Y_train)
    name = clf.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = clf.predict(X_test)
    acc = accuracy_score(Y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
    train_predictions = clf.predict_proba(X_test)
    ll = log_loss(Y_test, train_predictions)
    print("Log Loss: {}".format(ll))
    
    log_entry = pd.DataFrame([[name, acc*100, ll]], columns=log_cols)
    log = log.append(log_entry)
    
print("="*30)
# Out:
# ==============================
# MLPClassifier
# ****Results****
# Accuracy: 100.0000%
# Log Loss: 3.163188960588558e-05
# ==============================
# AdaBoostClassifier
# ****Results****
# Accuracy: 100.0000%
# Log Loss: 9.992007221626413e-16
# ==============================
# GradientBoostingClassifier
# ****Results****
# Accuracy: 100.0000%
# Log Loss: 0.00029189715643513877
# ==============================
# GaussianNB
# ****Results****
# Accuracy: 97.8836%
# Log Loss: 0.2143648569012648
# ==============================
# LinearDiscriminantAnalysis
# ****Results****
# Accuracy: 95.7672%
# Log Loss: 0.09160943478752577
# ==============================
# QuadraticDiscriminantAnalysis
# ****Results****
# Accuracy: 86.2434%
# Log Loss: 1.4047716848786138
# ==============================
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\sklearn\discriminant_analysis.py:693: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %% [markdown]
# For comparision purpose, We have printed Bar Graph for Classifier Accuracy and Classifier Log Loss.

# %%
sns.set_color_codes("muted")
sns.barplot(x='Accuracy', y='Classifier', data=log, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy')
plt.show()

sns.set_color_codes("muted")
sns.barplot(x='Log Loss', y='Classifier', data=log, color="g")

plt.xlabel('Log Loss')
plt.title('Classifier Log Loss')
plt.show()
